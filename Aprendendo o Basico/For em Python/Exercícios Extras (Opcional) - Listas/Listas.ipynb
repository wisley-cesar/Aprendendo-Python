# %% [markdown]
# # Listas
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que leia as vendas dos vendedores, mostre a venda de cada vendedor com o seu nome e a média de vendas.

# %%
vendas = [1000, 1500, 1200, 1300]
vendedores = ["Fulano", "Beltrano", "Ciclano", "Lira"]

for i, venda in enumerate(vendas):
    print(f'A o funcionario(a): {vendedores[i]} vendu {vendas[i]}.')

media = sum(vendas) / len(vendas)
print(f'A média de vendas é :{media:}')
# Out:
# A o funcionario(a): Fulano vendu 1000.
# A o funcionario(a): Beltrano vendu 1500.
# A o funcionario(a): Ciclano vendu 1200.
# A o funcionario(a): Lira vendu 1300.
# A média de vendas é :1250.0

# %% [markdown]
# #### 2. Faça um Programa que crie uma lista com as médias de cada aluno, imprima as médias de cada aluno e a quantidade de alunos com média maior que 7.

# %%
alunos = ["José", "Joana", "Maria", "Carla", "Mauricio", "Andre", "Tiago", "Enzo", "Amanda", "Alessandra"]
notas = [
    [10, 9, 8, 8],
    [9, 7, 6, 4],
    [10, 10, 10, 10],
    [5, 3, 10, 9],
    [7, 6, 6, 6],
    [7, 7, 8, 7],
    [7, 7, 7, 9],
    [8, 5, 6, 7],
    [10, 9, 7, 4],
    [10, 1, 3, 3],
]
meta = 7
qtd_alunos = 0
for i, nota in enumerate(notas):
    media = sum(nota)/ len(nota)
    print(f'o aluno(a) {alunos[i]} ficou com {media} na media.')
    if media > meta:
        qtd_alunos += 1
    
print(f'A quantida de alunos com media maior que {meta} foram: {qtd_alunos} alunos.')
# Out:
# o aluno(a) José ficou com 8.75 na media.
# o aluno(a) Joana ficou com 6.5 na media.
# o aluno(a) Maria ficou com 10.0 na media.
# o aluno(a) Carla ficou com 6.75 na media.
# o aluno(a) Mauricio ficou com 6.25 na media.
# o aluno(a) Andre ficou com 7.25 na media.
# o aluno(a) Tiago ficou com 7.5 na media.
# o aluno(a) Enzo ficou com 6.5 na media.
# o aluno(a) Amanda ficou com 7.5 na media.
# o aluno(a) Alessandra ficou com 4.25 na media.
# A quantida de alunos com media maior que 7 foram: 5 alunos.

# %% [markdown]
# #### 3. Foram anotadas as idades e salários de 30 funcionários. Faça um programa que determine quantos funcionários com mais de 25 anos possuem salário inferior à média de todos os salários.

# %%
idades = [35,32,50,33,48,50,33,48,22,49,35,38,20,47,49,48,34,21,48,44,48,30,25,42,42,23,25,23,38,35]
salarios = [3739,2219,3554,3978,4014,3270,4792,3879,2981,2384,4826,2460,3680,4318,1872,1770,4640,3929,3295,1729,3965,4267,4007,1916,2987,2943,3852,4543,2055,1730]

media_salario = sum(salarios)/ len(salarios)
idade_comparacao = 25
qtd_funcinario = 0

for i, idade in enumerate(idades):
    if idade_comparacao < idade:
        salario_funcionario = salarios[i]
        if salario_funcionario < media_salario :
            qtd_funcinario +=1 
print(f"são ao total {qtd_funcinario} funcionarios que possui salario inferior a média de todos os salários")
# Out:
# são ao total 12 funcionarios que possui salario inferior a média de todos os salários

# %% [markdown]
# #### 4.Em quais meses a média de temperatura foi maior do que a média nacional?

# %%
meses = [
    'Janeiro',
    'Fevereiro',
    'Março',
    'Abril',
    'Maio',
    'Junho',
    'Julho',
    'Agosto',
    'Setembro',
    'Outubro',
    'Novembro',
    'Dezembro'
]

temperaturas = [30, 29, 28, 28, 25, 26, 20, 21, 19, 25, 27, 32]

media = sum(temperaturas) / len(temperaturas)

for i , temperatura in enumerate(temperaturas):
    if media < temperatura :
        print(f'No mês de {meses[i]} a temperatura foi de {temperaturas[i]} sendo assim maior que a média nacional que é {media:.1f}')
# Out:
# No mês de Janeiro a temperatura foi de 30 sendo assim maior que a média nacional que é 25.8
# No mês de Fevereiro a temperatura foi de 29 sendo assim maior que a média nacional que é 25.8
# No mês de Março a temperatura foi de 28 sendo assim maior que a média nacional que é 25.8
# No mês de Abril a temperatura foi de 28 sendo assim maior que a média nacional que é 25.8
# No mês de Junho a temperatura foi de 26 sendo assim maior que a média nacional que é 25.8
# No mês de Novembro a temperatura foi de 27 sendo assim maior que a média nacional que é 25.8
# No mês de Dezembro a temperatura foi de 32 sendo assim maior que a média nacional que é 25.8

# %% [markdown]
# #### 5. As Organizações Tabajara resolveram dar um abono aos seus colaboradores em reconhecimento ao bom resultado alcançado durante o ano que passou. Para isto contratou você para desenvolver a aplicação que servirá como uma projeção de quanto será gasto com o pagamento deste abono.
# <pre>Após reuniões envolvendo a diretoria executiva, a diretoria financeira e os representantes do sindicato laboral, chegou-se a seguinte forma de cálculo:
# . Cada funcionário receberá o equivalente a 20% do seu salário bruto de dezembro;
# . O piso do abono será de 100 reais, isto é, aqueles funcionários cujo salário for muito baixo, recebem este valor mínimo;
#
# Neste momento, não se deve ter nenhuma preocupação com colaboradores com tempo menor de casa, descontos, impostos ou outras particularidades. O programa deverá calcular o valor do abono concedido a cada colaborador, de acordo com a regra definida acima. Ao final, o programa deverá apresentar:</pre>
# <pre>
# O salário de cada funcionário, juntamente com o valor do abono;
# O número total de funcionário processados;
# O valor total a ser gasto com o pagamento do abono;
# O número de funcionário que receberá o valor mínimo de 100 reais;
# O maior valor pago como abono; A tela abaixo é um exemplo de execução do programa, apenas para fins ilustrativos.
# <pre>
# Projeção de Gastos com Abono
# ============================
#
# Salário: 1000
# Salário: 300
# Salário: 500
# Salário: 100
# Salário: 4500
# Salário: 0
#
# Salário    - Abono
# R$ 1000.00 - R$  200.00
# R$  300.00 - R$  100.00
# R$  500.00 - R$  100.00
# R$  100.00 - R$  100.00
# R$ 4500.00 - R$  900.00
#
# Foram processados 5 colaboradores
# Total gasto com abonos: R$ 1400.00
# Valor mínimo pago a 3 colaboradores
# Maior valor de abono pago: R$ 900.00

# %%
lista_salarios = [1000, 300, 500, 200, 1500, 3000, 3400, 5000, 7000, 2000, 600, 800, 250, 1500, 20000]
abonos = []
contador = 0
print(f'=================================================================\n')
print(f'                Projeção de Gastos com Abono                     \n')
for i, salario in enumerate(lista_salarios):
    aumento_salario = (salario * 0.2)
    piso_minimo = 100
    if aumento_salario < piso_minimo:
        aumento_salario = 100
        contador +=1
    abonos.append(aumento_salario)
    print(f'Salário:R$ {lista_salarios[i]:,}        '   +  f'Abono:R$ {abonos[i]:,}')

print(f'\nForam preocessados {len(lista_salarios)} colaboradores.\nTotal gatos com abonos: R$ {sum(abonos):,}.\nValor mínimo pago a {contador} colaboradores.\nMaior valor de abono pago: R$ {max(abonos)}.')
# Out:
# =================================================================
#
#                 Projeção de Gastos com Abono
#
# Salário:R$ 1,000        Abono:R$ 200.0
# Salário:R$ 300        Abono:R$ 100
# Salário:R$ 500        Abono:R$ 100.0
# Salário:R$ 200        Abono:R$ 100
# Salário:R$ 1,500        Abono:R$ 300.0
# Salário:R$ 3,000        Abono:R$ 600.0
# Salário:R$ 3,400        Abono:R$ 680.0
# Salário:R$ 5,000        Abono:R$ 1,000.0
# Salário:R$ 7,000        Abono:R$ 1,400.0
# Salário:R$ 2,000        Abono:R$ 400.0
# Salário:R$ 600        Abono:R$ 120.0
# Salário:R$ 800        Abono:R$ 160.0
# Salário:R$ 250        Abono:R$ 100
# Salário:R$ 1,500        Abono:R$ 300.0
# Salário:R$ 20,000        Abono:R$ 4,000.0
#
# Foram preocessados 15 colaboradores.
# Total gatos com abonos: R$ 9,560.0.
# Valor mínimo pago a 3 colaboradores.
# Maior valor de abono pago: R$ 4000.0.

# %% [markdown]
# #### 6. Faça um programa que carregue uma lista com os modelos de cinco carros (exemplo de modelos: FUSCA, GOL, VECTRA etc). Carregue uma outra lista com o consumo desses carros, isto é, quantos quilômetros cada um desses carros faz com um litro de combustível. Calcule e mostre:
# <pre>
# a. O modelo do carro mais econômico;
# b. Quantos litros de combustível cada um dos carros cadastrados consome para percorrer uma distância de 1000 quilômetros e quanto isto custará, considerando um que a gasolina custe R$ 2,25 o litro. Abaixo segue uma tela de exemplo. O disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada execução do programa.</pre>
# ```
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Nome: fusca
# Km por litro: 7
# Veículo 2
# Nome: gol
# Km por litro: 10
# Veículo 3
# Nome: uno
# Km por litro: 12.5
# Veículo 4
# Nome: Vectra
# Km por litro: 9
# Veículo 5
# Nome: Peugeout
# Km por litro: 14.5
#
# Relatório Final
#  1 - fusca           -    7.0 -  142.9 litros - R$ 321.43
#  2 - gol             -   10.0 -  100.0 litros - R$ 225.00
#  3 - uno             -   12.5 -   80.0 litros - R$ 180.00
#  4 - vectra          -    9.0 -  111.1 litros - R$ 250.00
#  5 - peugeout        -   14.5 -   69.0 litros - R$ 155.17
# O menor consumo é do peugeout.
# ```

# %%
print('Comparativo de Consumo de Combustível')
veiculos = ['fusca','gol', 'uno', 'vectra', 'peugeot']
autonomias = [7, 10, 12.5, 9, 14.5]

print('Relatório Final')
for i, autonomia in enumerate(autonomias):
    mais_economico = min(autonomias)
    posicao = autonomias.index(mais_economico)
    qtd_combustivel =  1000 / autonomias[i] 
    print(f'O carro {veiculos[i]} faz {autonomias[i]} km por litro - cosumindo no total {qtd_combustivel:.1f} litros na viagem de 1000km - custando o tatal de R$ {qtd_combustivel * 2.25:,.2f}')



print(f'\nO carro mais economico é o {veiculos[posicao]}')
# Out:
# Comparativo de Consumo de Combustível
# Relatório Final
# O carro fusca faz 7 km por litro - cosumindo no total 142.9 litros na viagem de 1000km - custando o tatal de R$ 321.43
# O carro gol faz 10 km por litro - cosumindo no total 100.0 litros na viagem de 1000km - custando o tatal de R$ 225.00
# O carro uno faz 12.5 km por litro - cosumindo no total 80.0 litros na viagem de 1000km - custando o tatal de R$ 180.00
# O carro vectra faz 9 km por litro - cosumindo no total 111.1 litros na viagem de 1000km - custando o tatal de R$ 250.00
# O carro peugeot faz 14.5 km por litro - cosumindo no total 69.0 litros na viagem de 1000km - custando o tatal de R$ 155.17
#
# O carro mais economico é o fusca

# %% [markdown]
# #### 7. Uma empresa paga seus vendedores com base em comissões. O vendedor recebe \\$200 por semana mais 9 por cento de suas vendas brutas daquela semana. Por exemplo, um vendedor que teve vendas brutas de \\$3000 em uma semana recebe \\$200 mais 9 por cento de \\$3000, ou seja, um total de \\$470. Escreva um programa (usando um array de contadores) que determine quantos vendedores receberam salários nos seguintes intervalos de valores:
# <pre>
# $200 - $299
# $300 - $399
# $400 - $499
# $500 - $599
# $600 - $699
# $700 - $799
# $800 - $899
# $900 - $999
# $1000 em diante
# </pre>
#
# Existem várias formas de fazer. Faça primeiro da forma que parecer mais intuitiva para você.
#
# Em seguida, caso queira um desafio:
# Desafio: Crie uma forma para chegar na posição da lista a partir do salário, sem fazer vários ifs aninhados.

# %%
vendas = [1000, 2000, 3000, 4000, 5000, 6000, 5500, 4500, 3600]
salario_fixo = 200
lista_salario = []
for i, venda in enumerate(vendas):
    salario = (vendas[i] * 0.09) + salario_fixo
    lista_salario.append(salario)

    
print(lista_salario)
# Out:
# [290.0, 380.0, 470.0, 560.0, 650.0, 740.0, 695.0, 605.0, 524.0]
